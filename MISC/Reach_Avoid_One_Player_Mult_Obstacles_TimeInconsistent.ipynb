# %%
################################################################################
#
# Script to run an obstacle avoidance example for the TwoPlayerUnicycle4D.
#
################################################################################

import os
import numpy as np
import matplotlib.pyplot as plt

from obstacle_dist_cost import ObstacleDistCost
from car_5d import Car5D
from product_multiplayer_dynamical_system import \
    ProductMultiPlayerDynamicalSystem
from two_player_unicycle_4d import TwoPlayerUnicycle4D
#from ilq_solver_reach_avoid import ILQSolver            #Uncomment this (this is for the one-player one obstacle case)
from ilq_solver_mult_obs_try import ILQSolver            #Uncomment this (this is for the one-player multiple obstacle case)
from point import Point
from proximity_cost import ProximityCost
from obstacle_cost import ObstacleCost
from semiquadratic_cost import SemiquadraticCost
from quadratic_cost import QuadraticCost
#from player_cost import PlayerCost
from player_cost_reach_avoid import PlayerCost
from box_constraint import BoxConstraint
from visualizer import Visualizer
from logger import Logger
from semiquadratic_polyline_cost import SemiquadraticPolylineCost
from quadratic_polyline_cost import QuadraticPolylineCost
import sys
import signal

# General parameters.
TIME_HORIZON = 6.0   # s  #Change back to 2
TIME_RESOLUTION = 0.1 # s
HORIZON_STEPS = int(TIME_HORIZON / TIME_RESOLUTION)
LOG_DIRECTORY = "./logs/two_player_zero_sum/"
MAX_V = 7.0 # m/s

# Create dynamics.
car1 = Car5D(4.0)
dynamics = ProductMultiPlayerDynamicalSystem(
    [car1], T=TIME_RESOLUTION)

# Choose an initial state and control laws.
#car1_theta0 = np.pi / 2.0 # 90 degree heading # change back to 2.2!
car1_theta0 = np.pi / 6.0 # 90 degree heading # change back to 2.2!
car1_v0 = 5.0             # 5 m/s initial speed
car1_x0 = np.array([
    [4.5],
    [0.0],
    [car1_theta0],     #Originally 6.5, 0.0
    [0.0],
    [car1_v0]
])


# theta0 = np.pi / 10
# v0 = 5.0

# theta0 = np.pi / 6
# v0 = 5.0

x0 = car1_x0

P1s = [np.zeros((car1._u_dim, dynamics._x_dim))] * HORIZON_STEPS
alpha1s = [np.zeros((car1._u_dim, 1))] * HORIZON_STEPS

# Create the example environment. It will have a couple of circular obstacles
# laid out like this:
#                           x goal
#
#                      ()
#               ()
#                            ()
#
#          x start
goal = Point(6.5, 35.0)
goal_radius = 2.0

#obstacle_centers = [Point(6.5, 15.0)]
#obstacle_radii = [4.5]                             #Uncomment this (this is for one-player one obstacle)!!!!!
#car1_position_indices_in_product_state = (0, 1)

obstacle_centers = [Point(6.5, 15.0), Point(0.0, 20.0), Point(12.0, 24.0)]
obstacle_radii = [4.5, 1.5, 4.0]                                            #Uncomment this (this is for the one-player multiple obstacle case)!!!!!
car1_position_indices_in_product_state = (0, 1)

goal_cost = ProximityCost(car1_position_indices_in_product_state,
                          point=goal,
                          max_distance=np.inf,
                          apply_after_time=HORIZON_STEPS - 1,
                          name="goal")
obstacle_costs = [ObstacleCost(
    position_indices=(0, 1), point=p, max_distance=r,     #Uncomment this (this is for the one player multiple obstacle case)
    name="obstacle_%f_%f" % (p.x, p.y))
                  for p, r in zip(obstacle_centers, obstacle_radii)]

#for n in range(N):
    
#obstacle_costs = [ObstacleDistCost(
#    position_indices=(0, 1), point=p, max_distance=r,    #Uncomment this (this is for the one-player one obstacle case)
#    name="obstacle_%f_%f" % (p.x, p.y))
#                  for p, r in zip(obstacle_centers, obstacle_radii)]

w_cost = QuadraticCost(dimension=0, origin=0, name="w_cost")
a_cost = QuadraticCost(dimension=1, origin=0, name="a_cost")

#dvx_cost = QuadraticCost(dimension=0, origin=0, name="dvx_cost")
#dvy_cost = QuadraticCost(dimension=1, origin=0, name="dvy_cost")

# Add light quadratic around original values for theta/v.
v_cost_upper = SemiquadraticCost(
    dimension=3, threshold=MAX_V, oriented_right=True, name="v_cost_upper")
v_cost_lower = SemiquadraticCost(
    dimension=3, threshold=0, oriented_right=False, name="v_cost_lower")

# Polyline
#player1_position_indices_in_product_state = (0, 1)
#car1_polyline = Polyline([Point(6.5, 0.0), Point(6.5, 40.0)])
#car1_polyline_boundary_cost = SemiquadraticPolylineCost(
#    car1_polyline, 1.0, car1_position_indices_in_product_state,
#    "car1_polyline_boundary")
#car1_polyline_cost = QuadraticPolylineCost(
#    car1_polyline, car1_position_indices_in_product_state, "car1_polyline")

OBSTACLE_WEIGHT = 200.0 # HJI: 100
GOAL_WEIGHT = 50.0 # HJI: 400  #Change back to 100
#D_WEIGHT = 1000.0 # HJI: 1000
U_WEIGHT = 10.0 # HJI: 100

# V_WEIGHT = 100.0
V_WEIGHT = 0.1 # HJI: 50

# Build up total costs for both players. This is basically a zero-sum game.
player1_cost = PlayerCost()
player1_cost.add_cost(goal_cost, "x", GOAL_WEIGHT)
#for cost in obstacle_costs:
#    player1_cost.add_cost(cost, "x", OBSTACLE_WEIGHT)

#player1_cost.add_cost(v_cost_upper, "x", V_WEIGHT)
#player1_cost.add_cost(v_cost_lower, "x", V_WEIGHT)
#player1_cost.add_cost(w_cost, 0, U_WEIGHT)
#player1_cost.add_cost(a_cost, 0, U_WEIGHT)

# Visualizer.
visualizer = Visualizer(
    [(0, 1)],
    [goal_cost] + obstacle_costs,
    [".-b"],
    1,
    False,
    plot_lims=[-11, 100, 0, 100])

# Logger.
if not os.path.exists(LOG_DIRECTORY):
    os.makedirs(LOG_DIRECTORY)

path_to_logfile = os.path.join(LOG_DIRECTORY, "unicycle_4d_example.pkl")
if len(sys.argv) > 1:
    path_to_logfile = os.path.join(LOG_DIRECTORY, sys.argv[1])

print("Saving log file to {}...".format(path_to_logfile))
logger = Logger(path_to_logfile)

# Set up ILQSolver.
solver = ILQSolver(dynamics,
                   [player1_cost],
                   x0,
                   [P1s],
                   [alpha1s],
                   1.0,
                   None,
                   logger,
                   visualizer,
                   None,
                  [car1_position_indices_in_product_state, goal, obstacle_centers, obstacle_radii])

def handle_sigint(sig, frame):
    print("SIGINT caught! Saving log data...")
    logger.dump()
    print("...done, exiting!")
    sys.exit(0)

signal.signal(signal.SIGINT, handle_sigint)

solver.run()


#ProximityCost(car1_position_indices_in_product_state, goal, max_distance=np.inf, apply_after_time=HORIZON_STEPS - 1, name="goal")


#ObstacleDistCost(car1_position_indices_in_product_state, point=p, max_distance=r, name="obstacle_%f_%f" % (p.x, p.y)) for p, r in zip(obstacle_centers, obstacle_radii)


#[car1_position_indices_in_product_state, goal, obstacle_centers, obstacle_radii]
# Out:
# Saving log file to ./logs/two_player_zero_sum/-f...
# we are in target_marg
# target_marg_func at tau* is:  [27.31180768]
# time_star is:  38
# time_star is from def:  38
# Total cost for all players:  [27.311807677323085]
# current trajectory cost is:  [27.311807677323085]
# new trajectory cost is:  [26.77793977611905]
# step-size for this is:  1.0
# current trajectory cost is:  [27.311807677323085]
# new trajectory cost is:  [26.77793977611905]
# step-size for this is:  1.0
# /Users/duyn/Desktop/Princeton/RESEARCH/Reach-Avoid-Games/ilq_solver_mult_obs_try.py:231: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at  /Users/runner/miniforge3/conda-bld/pytorch-recipe_1635217280611/work/torch/csrc/utils/tensor_new.cpp:201.)
#   [torch.as_tensor(ui) for ui in us],
# we are in target_marg
# target_marg_func at tau* is:  [26.77793978]
# time_star is:  38
# time_star is from def:  38
# Total cost for all players:  [26.77793977611905]
# current trajectory cost is:  [26.77793977611905]
# new trajectory cost is:  [26.35659382764791]
# step-size for this is:  1.0
# current trajectory cost is:  [26.77793977611905]
# new trajectory cost is:  [26.35659382764791]
# step-size for this is:  1.0
# we are in target_marg
# target_marg_func at tau* is:  [26.35659383]
# time_star is:  37
# time_star is from def:  37
# Total cost for all players:  [26.35659382764791]
# current trajectory cost is:  [26.35659382764791]
# new trajectory cost is:  [26.00231255712918]
# step-size for this is:  1.0
# current trajectory cost is:  [26.35659382764791]
# new trajectory cost is:  [26.00231255712918]
# step-size for this is:  1.0
# we are in target_marg
# target_marg_func at tau* is:  [26.00231256]
# time_star is:  37
# time_star is from def:  37
# Total cost for all players:  [26.00231255712918]
# current trajectory cost is:  [26.00231255712918]
# new trajectory cost is:  [25.682350259701398]
# step-size for this is:  1.0
# current trajectory cost is:  [26.00231255712918]
# new trajectory cost is:  [25.682350259701398]
# step-size for this is:  1.0
# we are in target_marg
# target_marg_func at tau* is:  [25.68235026]
# time_star is:  37
# time_star is from def:  37
# Total cost for all players:  [25.682350259701398]
# current trajectory cost is:  [25.682350259701398]
# new trajectory cost is:  [25.366058483055934]
# step-size for this is:  1.0
# current trajectory cost is:  [25.682350259701398]
# new trajectory cost is:  [25.366058483055934]
# step-size for this is:  1.0
# we are in target_marg
# target_marg_func at tau* is:  [25.36605848]
# time_star is:  37
# time_star is from def:  37
# Total cost for all players:  [25.366058483055934]
# current trajectory cost is:  [25.366058483055934]
# new trajectory cost is:  [25.050921734215933]
# step-size for this is:  1.0
# current trajectory cost is:  [25.366058483055934]
# new trajectory cost is:  [25.050921734215933]
# step-size for this is:  1.0
# we are in target_marg
# target_marg_func at tau* is:  [25.05092173]
# time_star is:  37
# time_star is from def:  37
# Total cost for all players:  [25.050921734215933]
# current trajectory cost is:  [25.050921734215933]
# new trajectory cost is:  [24.744178289241184]
# step-size for this is:  1.0
# current trajectory cost is:  [25.050921734215933]
# new trajectory cost is:  [24.744178289241184]
# step-size for this is:  1.0
# we are in target_marg
# target_marg_func at tau* is:  [24.74417829]
# time_star is:  37
# time_star is from def:  37
# Total cost for all players:  [24.744178289241184]
# current trajectory cost is:  [24.744178289241184]
# new trajectory cost is:  [24.450294314345385]
# step-size for this is:  1.0
# current trajectory cost is:  [24.744178289241184]
# new trajectory cost is:  [24.450294314345385]
# step-size for this is:  1.0
# we are in target_marg
# target_marg_func at tau* is:  [24.45029431]
# time_star is:  37
# time_star is from def:  37
# Total cost for all players:  [24.450294314345385]
# current trajectory cost is:  [24.450294314345385]
# new trajectory cost is:  [24.168539943137592]
# step-size for this is:  1.0
# current trajectory cost is:  [24.450294314345385]
# new trajectory cost is:  [24.168539943137592]
# step-size for this is:  1.0
# we are in target_marg
# target_marg_func at tau* is:  [24.16853994]
# time_star is:  37
# time_star is from def:  37
# Total cost for all players:  [24.168539943137592]
# current trajectory cost is:  [24.168539943137592]
# new trajectory cost is:  [23.8958420056491]
# step-size for this is:  1.0
# current trajectory cost is:  [24.168539943137592]
# new trajectory cost is:  [23.8958420056491]
# step-size for this is:  1.0
# we are in target_marg
# target_marg_func at tau* is:  [23.89584201]
# time_star is:  37
# time_star is from def:  37
# Total cost for all players:  [23.8958420056491]
# current trajectory cost is:  [23.8958420056491]
# new trajectory cost is:  [23.62964806812273]
# step-size for this is:  1.0
# current trajectory cost is:  [23.8958420056491]
# new trajectory cost is:  [23.62964806812273]
# step-size for this is:  1.0
# we are in target_marg
# target_marg_func at tau* is:  [23.62964807]
# time_star is:  37
# time_star is from def:  37
# Total cost for all players:  [23.62964806812273]
# current trajectory cost is:  [23.62964806812273]
# new trajectory cost is:  [23.368875441432618]
# step-size for this is:  1.0
# current trajectory cost is:  [23.62964806812273]
# new trajectory cost is:  [23.368875441432618]
# step-size for this is:  1.0
# we are in target_marg
# target_marg_func at tau* is:  

# step-size for this is:  1.0
# we are in target_marg
# target_marg_func at tau* is:  [15.71369475]
# time_star is:  41
# time_star is from def:  41
# Total cost for all players:  [15.713694751582732]
# current trajectory cost is:  [15.713694751582732]
# new trajectory cost is:  [15.572158027563752]
# step-size for this is:  1.0
# current trajectory cost is:  [15.713694751582732]
# new trajectory cost is:  [15.572158027563752]
# step-size for this is:  1.0
# we are in target_marg
# target_marg_func at tau* is:  [15.57215803]
# time_star is:  41
# time_star is from def:  41
# Total cost for all players:  [15.572158027563752]
# current trajectory cost is:  [15.572158027563752]
# new trajectory cost is:  [15.430945797984336]
# step-size for this is:  1.0
# current trajectory cost is:  [15.572158027563752]
# new trajectory cost is:  [15.430945797984336]
# step-size for this is:  1.0
# we are in target_marg
# target_marg_func at tau* is:  [15.4309458]
# time_star is:  41
# time_star is from def:  41
# Total cost for all players:  [15.430945797984336]
# current trajectory cost is:  [15.430945797984336]
# new trajectory cost is:  [15.287735625165809]
# step-size for this is:  1.0
# current trajectory cost is:  [15.430945797984336]
# new trajectory cost is:  [15.287735625165809]
# step-size for this is:  1.0
# we are in target_marg
# target_marg_func at tau* is:  [15.28773563]
# time_star is:  41
# time_star is from def:  41
# Total cost for all players:  [15.287735625165809]
# current trajectory cost is:  [15.287735625165809]
# new trajectory cost is:  [15.143436222516534]
# step-size for this is:  1.0
# current trajectory cost is:  [15.287735625165809]
# new trajectory cost is:  [15.143436222516534]
# step-size for this is:  1.0
# we are in target_marg
# target_marg_func at tau* is:  [15.14343622]
# time_star is:  41
# time_star is from def:  41
# Total cost for all players:  [15.143436222516534]
# current trajectory cost is:  [15.143436222516534]
# new trajectory cost is:  [14.999428223538754]
# step-size for this is:  1.0
# current trajectory cost is:  [15.143436222516534]
# new trajectory cost is:  [14.999428223538754]
# step-size for this is:  1.0
# we are in target_marg
# target_marg_func at tau* is:  [14.99942822]
# time_star is:  42
# time_star is from def:  42
# Total cost for all players:  [14.999428223538754]
# current trajectory cost is:  [14.999428223538754]
# new trajectory cost is:  [14.836762527261094]
# step-size for this is:  1.0
# current trajectory cost is:  [14.999428223538754]
# new trajectory cost is:  [14.836762527261094]
# step-size for this is:  1.0
# we are in target_marg
# target_marg_func at tau* is:  [14.83676253]
# time_star is:  42
# time_star is from def:  42
# Total cost for all players:  [14.836762527261094]
# current trajectory cost is:  [14.836762527261094]
# new trajectory cost is:  [14.681127704047928]
# step-size for this is:  1.0
# current trajectory cost is:  [14.836762527261094]
# new trajectory cost is:  [14.681127704047928]
# step-size for this is:  1.0
# we are in target_marg
# target_marg_func at tau* is:  [14.6811277]
# time_star is:  42
# time_star is from def:  42
# Total cost for all players:  [14.681127704047928]
# current trajectory cost is:  [14.681127704047928]
# new trajectory cost is:  [14.537028415410074]
# step-size for this is:  1.0
# current trajectory cost is:  [14.681127704047928]
# new trajectory cost is:  [14.537028415410074]
# step-size for this is:  1.0
# we are in target_marg
# target_marg_func at tau* is:  [14.53702842]
# time_star is:  42
# time_star is from def:  42
# Total cost for all players:  [14.537028415410074]
# current trajectory cost is:  [14.537028415410074]
# new trajectory cost is:  [14.399849748884254]
# step-size for this is:  1.0
# current trajectory cost is:  [14.537028415410074]
# new trajectory cost is:  [14.399849748884254]
# step-size for this is:  1.0
# we are in target_marg
# target_marg_func at tau* is:  [14.39984975]
# time_star is:  42
# time_star is from def:  42
# Total cost for all players:  [14.399849748884254]
# current trajectory cost is:  [14.399849748884254]
# new trajectory cost is:  [14.264181275886703]
# step-size for this is:  1.0
# current trajectory cost is:  [14.399849748884254]
# new trajectory cost is:  [14.264181275886703]
# step-size for this is:  1.0
# we are in target_marg
# target_marg_func at tau* is:  [14.26418128]
# time_star is:  42
# time_star is from def:  42
# Total cost for all players:  [14.264181275886703]
# current trajectory cost is:  [14.264181275886703]
# new trajectory cost is:  [14.127647993500322]
# step-size for this is:  1.0
# current trajectory cost is:  [14.264181275886703]
# new trajectory cost is:  [14.127647993500322]
# step-size for this is:  1.0
# we are in target_marg
# target_marg_func at tau* is:  [14.12764799]
# time_star is:  42
# time_star is from def:  42
# Total cost for all players:  [14.127647993500322]
# current trajectory cost is:  [14.127647993500322]
# new trajectory cost is:  [13.990682176790248]
# step-size for this is:  1.0
# current trajectory cost is:  [14.127647993500322]
# new trajectory cost is:  [13.990682176790248]
# step-size for this is:  1.0
# we are in target_marg
# target_marg_func at tau* is:  [13.99068218]
# time_star is:  42
# time_star is from def:  42
# Total cost for all players:  [13.990682176790248]
# current trajectory cost is:  [13.990682176790248]
# new trajectory cost is:  [13.85296129902901]
# step-size for this is:  1.0
# current trajectory cost is:  [13.990682176790248]
# new trajectory cost is:  [13.85296129902901]
# step-size for this is:  1.0
# we are in target_marg
# target_marg_func at tau* is:  [13.8529613]
# time_star is:  43
# time_star is from def:  43
# Total cost for all players:  [13.85296129902901]
# current trajectory cost is:  [13.85296129902901]
# new trajectory cost is:  [13.694786705615975]
# step-size for this is:  1.0
# current trajectory cost is:  [13.85296129902901]
# new trajectory cost is:  [13.694786705615975]
# step-size for this is:  1.0
# we are in target_marg
# target_marg_func at tau* is:  [13.69478671]
# time_star is:  43
# time_star is from def:  43
# Total cost for all players:  [13.694786705615975]
# current trajectory cost is:  [13.694786705615975]
# new trajectory cost is:  [13.543120006967019]
# step-size for this is:  1.0
# current trajectory cost is:  [13.694786705615975]
# new trajectory cost is:  [13.543120006967019]
# step-size for this is:  1.0
# we are in target_marg
# target_marg_func at tau* is:  [13.54312001]
# time_star is:  43
# time_star is from def:  43
# Total cost for all players:  [13.543120006967019]
# current trajectory cost is:  [13.543120006967019]
# new trajectory cost is:  [13.402246629807017]
# step-size for this is:  1.0
# current trajectory cost is:  [13.543120006967019]
# new trajectory cost is:  [13.402246629807017]
# step-size for this is:  1.0
# we are in target_marg
# target_marg_func at tau* is:  [13.40224663]
# time_star is:  43
# time_star is from def:  43
# Total cost for all players:  [13.402246629807017]
# current trajectory cost is:  [13.402246629807017]
# new trajectory cost is:  [13.26767392522606]
# step-size for this is:  1.0
# current trajectory cost is:  [13.402246629807017]
# new trajectory cost is:  [13.26767392522606]
# step-size for this is:  1.0
# we are in target_marg
# target_marg_func at tau* is:  [13.26767393]
# time_star is:  43
# time_star is from def:  43
# Total cost for all players:  [13.26767392522606]
# current trajectory cost is:  [13.26767392522606]
# new trajectory cost is:  [13.13437976478835]
# step-size for this is:  1.0
# current trajectory cost is:  [13.26767392522606]
# new trajectory cost is:  [13.13437976478835]
# step-size for this is:  1.0
# we are in target_marg
# target_marg_func at tau* is:  [13.13437976]
# time_star is:  43
# time_star is from def:  43
# Total cost for all players:  [13.13437976478835]
# current trajectory cost is:  [13.13437976478835]
# new trajectory cost is:  [13.000480966709473]
# step-size for this is:  1.0
# current trajectory cost is:  [13.13437976478835]
# new trajectory cost is:  [13.000480966709473]
# step-size for this is:  1.0
# we are in target_marg
# target_marg_func at tau* is:  [13.00048097]
# time_star is:  43
# time_star is from def:  43
# Total cost for all players:  [13.000480966709473]
# current trajectory cost is:  [13.000480966709473]
# new trajectory cost is:  [12.866823807324112]
# step-size for this is:  1.0
# current trajectory cost is:  [13.000480966709473]
# new trajectory cost is:  [12.866823807324112]
# step-size for this is:  1.0
# we are in target_marg
# target_marg_func at tau* is:  [12.86682381]
# time_star is:  43
# time_star is from def:  43
# Total cost for all players:  [12.866823807324112]
# current trajectory cost is:  [12.866823807324112]
# new trajectory cost is:  [12.73153091345248]
# step-size for this is:  1.0
# current trajectory cost is:  [12.866823807324112]
# new trajectory cost is:  [12.73153091345248]
# step-size for this is:  1.0
# we are in target_marg
# target_marg_func at tau* is:  [12.73153091]
# time_star is:  44
# time_star is from def:  44
# Total cost for all players:  [12.73153091345248]
# current trajectory cost is:  [12.73153091345248]
# new trajectory cost is:  [12.575904350995536]
# step-size for this is:  1.0
# current trajectory cost is:  [12.73153091345248]
# new trajectory cost is:  [12.575904350995536]
# step-size for this is:  1.0
# we are in target_marg
# target_marg_func at tau* is:  [12.57590435]
# time_star is:  44
# time_star is from def:  44
# Total cost for all players:  [12.575904350995536]
# current trajectory cost is:  [12.575904350995536]
# new trajectory cost is:  [12.427730455655762]
# step-size for this is:  1.0
# current trajectory cost is:  [12.575904350995536]
# new trajectory cost is:  [12.427730455655762]
# step-size for this is:  1.0
# we are in target_marg
# target_marg_func at tau* is:  [12.42773046]
# time_star is:  44
# time_star is from def:  44
# Total cost for all players:  [12.427730455655762]
# current trajectory cost is:  [12.427730455655762]
# new trajectory cost is:  [12.29065073610385]
# step-size for this is:  1.0
# current trajectory cost is:  [12.427730455655762]
# new trajectory cost is:  [12.29065073610385]
# step-size for this is:  1.0
# we are in target_marg
# target_marg_func at tau* is:  [12.29065074]
# time_star is:  44
# time_star is from def:  44
# Total cost for all players:  [12.29065073610385]
# current trajectory cost is:  [12.29065073610385]
# new trajectory cost is:  [12.159580744969983]
# step-size for this is:  1.0
# current trajectory cost is:  [12.29065073610385]
# new trajectory cost is:  [12.159580744969983]
# step-size for this is:  1.0
# we are in target_marg
# target_marg_func at tau* is:  [12.15958074]
# time_star is:  44
# time_star is from def:  44
# Total cost for all players:  [12.159580744969983]
# current trajectory cost is:  [12.159580744969983]
# new trajectory cost is:  [12.029055066917019]
# step-size for this is:  1.0
# current trajectory cost is:  [12.159580744969983]
# new trajectory cost is:  [12.029055066917019]
# step-size for this is:  1.0
# we are in target_marg
# target_marg_func at tau* is:  [12.02905507]
# time_star is:  44
# time_star is from def:  44
# Total cost for all players:  [12.029055066917019]
# current trajectory cost is:  [12.029055066917019]
# new trajectory cost is:  [11.89703685257857]
# step-size for this is:  1.0
# current trajectory cost is:  [12.029055066917019]
# new trajectory cost is:  [11.89703685257857]
# step-size for this is:  1.0
# we are in target_marg
# target_marg_func at tau* is:  [11.89703685]
# time_star is:  44
# time_star is from def:  44
# Total cost for all players:  [11.89703685257857]
# current trajectory cost is:  [11.89703685257857]
# new trajectory cost is:  [11.764578480067646]
# step-size for this is:  1.0
# current trajectory cost is:  [11.89703685257857]
# new trajectory cost is:  [11.764578480067646]
# step-size for this is:  1.0
# we are in target_marg
# target_marg_func at tau* is:  [11.76457848]
# time_star is:  44
# time_star is from def:  44
# Total cost for all players:  [11.764578480067646]
# current trajectory cost is:  [11.764578480067646]
# new trajectory cost is:  [11.62754074837925]
# step-size for this is:  1.0
# current trajectory cost is:  [11.764578480067646]
# new trajectory cost is:  [11.62754074837925]
# step-size for this is:  1.0
# we are in target_marg
# target_marg_func at tau* is:  [11.62754075]
# time_star is:  45
# time_star is from def:  45
# Total cost for all players:  [11.62754074837925]
# current trajectory cost is:  [11.62754074837925]
# new trajectory cost is:  [11.470850120633436]
# step-size for this is:  1.0
# current trajectory cost is:  [11.62754074837925]
# new trajectory cost is:  [11.470850120633436]
# step-size for this is:  1.0
# we are in target_marg
# target_marg_func at tau* is:  [11.47085012]
# time_star is:  45
# time_star is from def:  45
# Total cost for all players:  [11.470850120633436]
# current trajectory cost is:  [11.470850120633436]
# new trajectory cost is:  [11.322970451438142]
# step-size for this is:  1.0
# current trajectory cost is:  [11.470850120633436]
# new trajectory cost is:  [11.322970451438142]
# step-size for this is:  1.0
# we are in target_marg
# target_marg_func at tau* is:  [11.32297045]
# time_star is:  45
# time_star is from def:  45
# Total cost for all players:  [11.322970451438142]
# current trajectory cost is:  [11.322970451438142]
# new trajectory cost is:  [11.187547145827141]
# step-size for this is:  1.0
# current trajectory cost is:  [11.322970451438142]
# new trajectory cost is:  [11.187547145827141]
# step-size for this is:  1.0
# we are in target_marg
# target_marg_func at tau* is:  [11.18754715]
# time_star is:  45
# time_star is from def:  45
# Total cost for all players:  [11.187547145827141]
# current trajectory cost is:  [11.187547145827141]
# new trajectory cost is:  [11.059245450059672]
# step-size for this is:  1.0
# current trajectory cost is:  [11.187547145827141]
# new trajectory cost is:  [11.059245450059672]
# step-size for this is:  1.0
# we are in target_marg
# target_marg_func at tau* is:  [11.05924545]
# time_star is:  45
# time_star is from def:  45
# Total cost for all players:  [11.059245450059672]
# current trajectory cost is:  [11.059245450059672]
# new trajectory cost is:  [10.932070377669104]
# step-size for this is:  1.0
# current trajectory cost is:  [11.059245450059672]
# new trajectory cost is:  [10.932070377669104]
# step-size for this is:  1.0
# we are in target_marg
# target_marg_func at tau* is:  [10.93207038]
# time_star is:  45
# time_star is from def:  45
# Total cost for all players:  [10.932070377669104]
# current trajectory cost is:  [10.932070377669104]
# new trajectory cost is:  [10.803341873838713]
# step-size for this is:  1.0
# current trajectory cost is:  [10.932070377669104]
# new trajectory cost is:  [10.803341873838713]
# step-size for this is:  1.0
# we are in target_marg
# target_marg_func at tau* is:  [10.80334187]
# time_star is:  45
# time_star is from def:  45
# Total cost for all players:  [10.803341873838713]
# current trajectory cost is:  [10.803341873838713]
# new trajectory cost is:  [10.670309807298372]
# step-size for this is:  1.0
# current trajectory cost is:  [10.803341873838713]
# new trajectory cost is:  [10.670309807298372]
# step-size for this is:  1.0
# we are in target_marg
# target_marg_func at tau* is:  [10.67030981]
# time_star is:  46
# time_star is from def:  46
# Total cost for all players:  [10.670309807298372]
# current trajectory cost is:  [10.670309807298372]
# new trajectory cost is:  [10.508809354152037]
# step-size for this is:  1.0
# current trajectory cost is:  [10.670309807298372]
# new trajectory cost is:  [10.508809354152037]
# step-size for this is:  1.0
# we are in target_marg
# target_marg_func at tau* is:  [10.50880935]
# time_star is:  46
# time_star is from def:  46
# Total cost for all players:  [10.508809354152037]
# current trajectory cost is:  [10.508809354152037]
# new trajectory cost is:  [10.355227075010621]
# step-size for this is:  1.0
# current trajectory cost is:  [10.508809354152037]
# new trajectory cost is:  [10.355227075010621]
# step-size for this is:  1.0
# we are in target_marg
# target_marg_func at tau* is:  [10.35522708]
# time_star is:  46
# time_star is from def:  46
# Total cost for all players:  [10.355227075010621]
# current trajectory cost is:  [10.355227075010621]
# new trajectory cost is:  [10.214428824466898]
# step-size for this is:  1.0
# current trajectory cost is:  [10.355227075010621]
# new trajectory cost is:  [10.214428824466898]
# step-size for this is:  1.0
# we are in target_marg
# target_marg_func at tau* is:  [10.21442882]
# time_star is:  46
# time_star is from def:  46
# Total cost for all players:  [10.214428824466898]
# current trajectory cost is:  [10.214428824466898]
# new trajectory cost is:  [10.082074880362951]
# step-size for this is:  1.0
# current trajectory cost is:  [10.214428824466898]
# new trajectory cost is:  [10.082074880362951]
# step-size for this is:  1.0
# we are in target_marg
# target_marg_func at tau* is:  [10.08207488]
# time_star is:  46
# time_star is from def:  46
# Total cost for all players:  [10.082074880362951]
# current trajectory cost is:  [10.082074880362951]
# new trajectory cost is:  [9.952662055415473]
# step-size for this is:  1.0
# current trajectory cost is:  [10.082074880362951]
# new trajectory cost is:  [9.952662055415473]
# step-size for this is:  1.0
# we are in target_marg
# target_marg_func at tau* is:  [9.95266206]
# time_star is:  46
# time_star is from def:  46
# Total cost for all players:  [9.952662055415473]
# current trajectory cost is:  [9.952662055415473]
# new trajectory cost is:  [9.82345982618714]
# step-size for this is:  1.0
# current trajectory cost is:  [9.952662055415473]
# new trajectory cost is:  [9.82345982618714]
# step-size for this is:  1.0
# we are in target_marg
# target_marg_func at tau* is:  [9.82345983]
# time_star is:  46
# time_star is from def:  46
# Total cost for all players:  [9.82345982618714]
# current trajectory cost is:  [9.82345982618714]
# new trajectory cost is:  [9.694533541425479]
# step-size for this is:  1.0
# current trajectory cost is:  [9.82345982618714]
# new trajectory cost is:  [9.694533541425479]
# step-size for this is:  1.0
# we are in target_marg
# target_marg_func at tau* is:  [9.69453354]
# time_star is:  47
# time_star is from def:  47
# Total cost for all players:  [9.694533541425479]
# current trajectory cost is:  [9.694533541425479]
# new trajectory cost is:  [9.530878467715642]
# step-size for this is:  1.0
# current trajectory cost is:  [9.694533541425479]
# new trajectory cost is:  [9.530878467715642]
# step-size for this is:  1.0
# we are in target_marg
# target_marg_func at tau* is:  [9.53087847]
# time_star is:  47
# time_star is from def:  47
# Total cost for all players:  [9.530878467715642]
# current trajectory cost is:  [9.530878467715642]
# new trajectory cost is:  [9.376060941324754]
# step-size for this is:  1.0
# current trajectory cost is:  [9.530878467715642]
# new trajectory cost is:  [9.376060941324754]
# step-size for this is:  1.0
# we are in target_marg
# target_marg_func at tau* is:  [9.37606094]
# time_star is:  47
# time_star is from def:  47
# Total cost for all players:  [9.376060941324754]
# current trajectory cost is:  [9.376060941324754]
# new trajectory cost is:  [9.23439926704615]
# step-size for this is:  1.0
# current trajectory cost is:  [9.376060941324754]
# new trajectory cost is:  [9.23439926704615]
# step-size for this is:  1.0
# we are in target_marg
# target_marg_func at tau* is:  [9.23439927]
# time_star is:  47
# time_star is from def:  47
# Total cost for all players:  [9.23439926704615]
# current trajectory cost is:  [9.23439926704615]
# new trajectory cost is:  [9.10126909257588]
# step-size for this is:  1.0
# current trajectory cost is:  [9.23439926704615]
# new trajectory cost is:  [9.10126909257588]
# step-size for this is:  1.0
# we are in target_marg
# target_marg_func at tau* is:  [9.10126909]
# time_star is:  47
# time_star is from def:  47
# Total cost for all players:  [9.10126909257588]
# current trajectory cost is:  [9.10126909257588]
# new trajectory cost is:  [8.970964187800273]
# step-size for this is:  1.0
# current trajectory cost is:  [9.10126909257588]
# new trajectory cost is:  [8.970964187800273]
# step-size for this is:  1.0
# we are in target_marg
# target_marg_func at tau* is:  [8.97096419]
# time_star is:  47
# time_star is from def:  47
# Total cost for all players:  [8.970964187800273]
# current trajectory cost is:  [8.970964187800273]
# new trajectory cost is:  [8.840665348305617]
# step-size for this is:  1.0
# current trajectory cost is:  [8.970964187800273]
# new trajectory cost is:  [8.840665348305617]
# step-size for this is:  1.0
# we are in target_marg
# target_marg_func at tau* is:  [8.84066535]
# time_star is:  47
# time_star is from def:  47
# Total cost for all players:  [8.840665348305617]
# current trajectory cost is:  [8.840665348305617]
# new trajectory cost is:  [8.71053029542336]
# step-size for this is:  1.0
# current trajectory cost is:  [8.840665348305617]
# new trajectory cost is:  [8.71053029542336]
# step-size for this is:  1.0
# we are in target_marg
# target_marg_func at tau* is:  [8.7105303]
# time_star is:  47
# time_star is from def:  47
# Total cost for all players:  [8.71053029542336]
# current trajectory cost is:  [8.71053029542336]
# new trajectory cost is:  [8.574692215638327]
# step-size for this is:  1.0
# current trajectory cost is:  [8.71053029542336]
# new trajectory cost is:  [8.574692215638327]
# step-size for this is:  1.0
# we are in target_marg
# target_marg_func at tau* is:  [8.57469222]
# time_star is:  48
# time_star is from def:  48
# Total cost for all players:  [8.574692215638327]
# current trajectory cost is:  [8.574692215638327]
# new trajectory cost is:  [8.40986538409364]
# step-size for this is:  1.0
# current trajectory cost is:  [8.574692215638327]
# new trajectory cost is:  [8.40986538409364]
# step-size for this is:  1.0
# we are in target_marg
# target_marg_func at tau* is:  [8.40986538]
# time_star is:  48
# time_star is from def:  48
# Total cost for all players:  [8.40986538409364]
# current trajectory cost is:  [8.40986538409364]
# new trajectory cost is:  [8.256350094918362]
# step-size for this is:  1.0
# current trajectory cost is:  [8.40986538409364]
# new trajectory cost is:  [8.256350094918362]
# step-size for this is:  1.0
# we are in target_marg
# target_marg_func at tau* is:  [8.25635009]
# time_star is:  48
# time_star is from def:  48
# Total cost for all players:  [8.256350094918362]
# current trajectory cost is:  [8.256350094918362]
# new trajectory cost is:  [8.11739638452909]
# step-size for this is:  1.0
# current trajectory cost is:  [8.256350094918362]
# new trajectory cost is:  [8.11739638452909]
# step-size for this is:  1.0
# we are in target_marg
# target_marg_func at tau* is:  [8.11739638]
# time_star is:  48
# time_star is from def:  48
# Total cost for all players:  [8.11739638452909]
# current trajectory cost is:  [8.11739638452909]
# new trajectory cost is:  [7.987582222960858]
# step-size for this is:  1.0
# current trajectory cost is:  [8.11739638452909]
# new trajectory cost is:  [7.987582222960858]
# step-size for this is:  1.0
# we are in target_marg
# target_marg_func at tau* is:  [7.98758222]
# time_star is:  48
# time_star is from def:  48
# Total cost for all players:  [7.987582222960858]
# current trajectory cost is:  [7.987582222960858]
# new trajectory cost is:  [7.860509701986642]
# step-size for this is:  1.0
# current trajectory cost is:  [7.987582222960858]
# new trajectory cost is:  [7.860509701986642]
# step-size for this is:  1.0
# we are in target_marg
# target_marg_func at tau* is:  [7.8605097]
# time_star is:  48
# time_star is from def:  48
# Total cost for all players:  [7.860509701986642]
# current trajectory cost is:  [7.860509701986642]
# new trajectory cost is:  [7.732825166356337]
# step-size for this is:  1.0
# current trajectory cost is:  [7.860509701986642]
# new trajectory cost is:  [7.732825166356337]
# step-size for this is:  1.0
# we are in target_marg
# target_marg_func at tau* is:  [7.73282517]
# time_star is:  48
# time_star is from def:  48
# Total cost for all players:  [7.732825166356337]
# current trajectory cost is:  [7.732825166356337]
# new trajectory cost is:  [7.5983872643598165]
# step-size for this is:  1.0
# current trajectory cost is:  [7.732825166356337]
# new trajectory cost is:  [7.5983872643598165]
# step-size for this is:  1.0
# we are in target_marg
# target_marg_func at tau* is:  [7.59838726]
# time_star is:  49
# time_star is from def:  49
# Total cost for all players:  [7.5983872643598165]
# current trajectory cost is:  [7.5983872643598165]
# new trajectory cost is:  [7.427027998311196]
# step-size for this is:  1.0
# current trajectory cost is:  [7.5983872643598165]
# new trajectory cost is:  [7.427027998311196]
# step-size for this is:  1.0
# we are in target_marg
# target_marg_func at tau* is:  [7.427028]
# time_star is:  49
# time_star is from def:  49
# Total cost for all players:  [7.427027998311196]
# current trajectory cost is:  [7.427027998311196]
# new trajectory cost is:  [7.2667339461338525]
# step-size for this is:  1.0
# current trajectory cost is:  [7.427027998311196]
# new trajectory cost is:  [7.2667339461338525]
# step-size for this is:  1.0
# we are in target_marg
# target_marg_func at tau* is:  [7.26673395]
# time_star is:  49
# time_star is from def:  49
# Total cost for all players:  [7.2667339461338525]
# current trajectory cost is:  [7.2667339461338525]
# new trajectory cost is:  [7.121690989239916]
# step-size for this is:  1.0
# current trajectory cost is:  [7.2667339461338525]
# new trajectory cost is:  [7.121690989239916]
# step-size for this is:  1.0
# we are in target_marg
# target_marg_func at tau* is:  [7.12169099]
# time_star is:  49
# time_star is from def:  49
# Total cost for all players:  [7.121690989239916]
# current trajectory cost is:  [7.121690989239916]
# new trajectory cost is:  [6.987380580474047]
# step-size for this is:  1.0
# current trajectory cost is:  [7.121690989239916]
# new trajectory cost is:  [6.987380580474047]
# step-size for this is:  1.0
# we are in target_marg
# target_marg_func at tau* is:  [6.98738058]
# time_star is:  49
# time_star is from def:  49
# Total cost for all players:  [6.987380580474047]
# current trajectory cost is:  [6.987380580474047]
# new trajectory cost is:  [6.857762940108017]
# step-size for this is:  1.0
# current trajectory cost is:  [6.987380580474047]
# new trajectory cost is:  [6.857762940108017]
# step-size for this is:  1.0
# we are in target_marg
# target_marg_func at tau* is:  [6.85776294]
# time_star is:  49
# time_star is from def:  49
# Total cost for all players:  [6.857762940108017]
# current trajectory cost is:  [6.857762940108017]
# new trajectory cost is:  [6.729235083772883]
# step-size for this is:  1.0
# current trajectory cost is:  [6.857762940108017]
# new trajectory cost is:  [6.729235083772883]
# ...
# target_marg_func at tau* is:  [5.9761175]
# time_star is:  50
# time_star is from def:  50
# Total cost for all players:  [5.976117498293932]
# current trajectory cost is:  [5.976117498293932]
# new trajectory cost is:  [5.846271265755725]
# step-size for this is:  1.0
# current trajectory cost is:  [5.976117498293932]
# new trajectory cost is:  [5.846271265755725]
# step-size for this is:  1.0
# we are in target_marg
# target_marg_func at tau* is:  [5.84627127]
# time_star is:  50
# time_star is from def:  50
# Total cost for all players:  [5.846271265755725]
# current trajectory cost is:  [5.846271265755725]
# new trajectory cost is:  [5.718216655858482]
# step-size for this is:  1.0
# current trajectory cost is:  [5.846271265755725]
# new trajectory cost is:  [5.718216655858482]
# step-size for this is:  1.0
# we are in target_marg
# target_marg_func at tau* is:  [5.71821666]
# time_star is:  50
# time_star is from def:  50
# Total cost for all players:  [5.718216655858482]
# current trajectory cost is:  [5.718216655858482]
# new trajectory cost is:  [5.587720252362533]
# step-size for this is:  1.0
# current trajectory cost is:  [5.718216655858482]
# new trajectory cost is:  [5.587720252362533]
# step-size for this is:  1.0
# we are in target_marg
# target_marg_func at tau* is:  [5.58772025]
# time_star is:  51
# time_star is from def:  51
# Total cost for all players:  [5.587720252362533]
# current trajectory cost is:  [5.587720252362533]
# new trajectory cost is:  [5.407830583374477]
# step-size for this is:  1.0
# current trajectory cost is:  [5.587720252362533]
# new trajectory cost is:  [5.407830583374477]
# step-size for this is:  1.0
# we are in target_marg
# target_marg_func at tau* is:  [5.40783058]
# time_star is:  51
# time_star is from def:  51
# Total cost for all players:  [5.407830583374477]
# current trajectory cost is:  [5.407830583374477]
# new trajectory cost is:  [5.241948558819131]
# step-size for this is:  1.0
# current trajectory cost is:  [5.407830583374477]
# new trajectory cost is:  [5.241948558819131]
# step-size for this is:  1.0
# we are in target_marg
# target_marg_func at tau* is:  [5.24194856]
# time_star is:  51
# time_star is from def:  51
# Total cost for all players:  [5.241948558819131]
# current trajectory cost is:  [5.241948558819131]
# new trajectory cost is:  [5.093182672649183]
# step-size for this is:  1.0
# current trajectory cost is:  [5.241948558819131]
# new trajectory cost is:  [5.093182672649183]
# step-size for this is:  1.0
# we are in target_marg
# target_marg_func at tau* is:  [5.09318267]
# time_star is:  51
# time_star is from def:  51
# Total cost for all players:  [5.093182672649183]
# current trajectory cost is:  [5.093182672649183]
# new trajectory cost is:  [4.956828025548434]
# step-size for this is:  1.0
# current trajectory cost is:  [5.093182672649183]
# new trajectory cost is:  [4.956828025548434]
# step-size for this is:  1.0
# we are in target_marg
# target_marg_func at tau* is:  [4.95682803]
# time_star is:  51
# time_star is from def:  51
# Total cost for all players:  [4.956828025548434]
# current trajectory cost is:  [4.956828025548434]
# new trajectory cost is:  [4.826671076066674]
# step-size for this is:  1.0
# current trajectory cost is:  [4.956828025548434]
# new trajectory cost is:  [4.826671076066674]
# step-size for this is:  1.0
# we are in target_marg
# target_marg_func at tau* is:  [4.82667108]
# time_star is:  51
# time_star is from def:  51
# Total cost for all players:  [4.826671076066674]
# current trajectory cost is:  [4.826671076066674]
# new trajectory cost is:  [4.698711429952572]
# step-size for this is:  1.0
# current trajectory cost is:  [4.826671076066674]
# new trajectory cost is:  [4.698711429952572]
# step-size for this is:  1.0
# we are in target_marg
# target_marg_func at tau* is:  [4.69871143]
# time_star is:  51
# time_star is from def:  51
# Total cost for all players:  [4.698711429952572]
# current trajectory cost is:  [4.698711429952572]
# new trajectory cost is:  [4.569173746828069]
# step-size for this is:  1.0
# current trajectory cost is:  [4.698711429952572]
# new trajectory cost is:  [4.569173746828069]
# step-size for this is:  1.0
# we are in target_marg
# target_marg_func at tau* is:  [4.56917375]
# time_star is:  52
# time_star is from def:  52
# Total cost for all players:  [4.569173746828069]
# current trajectory cost is:  [4.569173746828069]
# new trajectory cost is:  [4.38294201385721]
# step-size for this is:  1.0
# current trajectory cost is:  [4.569173746828069]
# new trajectory cost is:  [4.38294201385721]
# step-size for this is:  1.0
# we are in target_marg
# target_marg_func at tau* is:  [4.38294201]
# time_star is:  52
# time_star is from def:  52
# Total cost for all players:  [4.38294201385721]
# current trajectory cost is:  [4.38294201385721]
# new trajectory cost is:  [4.21269275129816]
# step-size for this is:  1.0
# current trajectory cost is:  [4.38294201385721]
# new trajectory cost is:  [4.21269275129816]
# step-size for this is:  1.0
# we are in target_marg
# target_marg_func at tau* is:  [4.21269275]
# time_star is:  52
# time_star is from def:  52
# Total cost for all players:  [4.21269275129816]
# current trajectory cost is:  [4.21269275129816]
# new trajectory cost is:  [4.0612152181369465]
# step-size for this is:  1.0
# current trajectory cost is:  [4.21269275129816]
# new trajectory cost is:  [4.0612152181369465]
# step-size for this is:  1.0
# we are in target_marg
# target_marg_func at tau* is:  [4.06121522]
# time_star is:  52
# time_star is from def:  52
# Total cost for all players:  [4.0612152181369465]
# current trajectory cost is:  [4.0612152181369465]
# new trajectory cost is:  [3.9238035833986835]
# step-size for this is:  1.0
# current trajectory cost is:  [4.0612152181369465]
# new trajectory cost is:  [3.9238035833986835]
# step-size for this is:  1.0
# we are in target_marg
# target_marg_func at tau* is:  [3.92380358]
# time_star is:  52
# time_star is from def:  52
# Total cost for all players:  [3.9238035833986835]
# current trajectory cost is:  [3.9238035833986835]
# new trajectory cost is:  [3.7940458886046606]
# step-size for this is:  1.0
# current trajectory cost is:  [3.9238035833986835]
# new trajectory cost is:  [3.7940458886046606]
# step-size for this is:  1.0
# we are in target_marg
# target_marg_func at tau* is:  [3.79404589]
# time_star is:  52
# time_star is from def:  52
# Total cost for all players:  [3.7940458886046606]
# current trajectory cost is:  [3.7940458886046606]
# new trajectory cost is:  [3.667421652107029]
# step-size for this is:  1.0
# current trajectory cost is:  [3.7940458886046606]
# new trajectory cost is:  [3.667421652107029]
# step-size for this is:  1.0
# we are in target_marg
# target_marg_func at tau* is:  [3.66742165]
# time_star is:  52
# time_star is from def:  52
# Total cost for all players:  [3.667421652107029]
# current trajectory cost is:  [3.667421652107029]
# new trajectory cost is:  [3.5394428564171374]
# step-size for this is:  1.0
# current trajectory cost is:  [3.667421652107029]
# new trajectory cost is:  [3.5394428564171374]
# step-size for this is:  1.0
# we are in target_marg
# target_marg_func at tau* is:  [3.53944286]
# time_star is:  53
# time_star is from def:  53
# Total cost for all players:  [3.5394428564171374]
# current trajectory cost is:  [3.5394428564171374]
# new trajectory cost is:  [3.34473319429015]
# step-size for this is:  1.0
# current trajectory cost is:  [3.5394428564171374]
# new trajectory cost is:  [3.34473319429015]
# step-size for this is:  1.0
# we are in target_marg
# target_marg_func at tau* is:  [3.34473319]
# time_star is:  53
# time_star is from def:  53
# Total cost for all players:  [3.34473319429015]
# a is:  39
# b is:  2
# c is:  (12.0, 24.0)
# current trajectory cost is:  [3.34473319429015]
# new trajectory cost is:  [3.3079933953819007]
# step-size for this is:  1.0
# a is:  39
# b is:  2
# c is:  (12.0, 24.0)
# current trajectory cost is:  [3.34473319429015]
# new trajectory cost is:  [3.3079933953819007]
# step-size for this is:  1.0
# obs_marg_func at tau* is:  [3.3079934]
# we are in obstacle_marg
# time_star is:  39
# time_star is from def:  39
# Total cost for all players:  [3.3079933953819007]
# current trajectory cost is:  [3.3079933953819007]
# new trajectory cost is:  [3.2994281553241853]
# step-size for this is:  0.25418658283290013
# current trajectory cost is:  [3.3079933953819007]
# new trajectory cost is:  [3.2994281553241853]
# step-size for this is:  0.25418658283290013
# we are in target_marg
# target_marg_func at tau* is:  [3.29942816]
# time_star is:  53
# time_star is from def:  53
# Total cost for all players:  [3.2994281553241853]
# a is:  39
# b is:  2
# c is:  (12.0, 24.0)
# current trajectory cost is:  [3.2994281553241853]
# new trajectory cost is:  [3.1632115844095883]
# step-size for this is:  1.0
# a is:  39
# b is:  2
# c is:  (12.0, 24.0)
# current trajectory cost is:  [3.2994281553241853]
# new trajectory cost is:  [3.1632115844095883]
# step-size for this is:  1.0
# obs_marg_func at tau* is:  [3.16321158]
# we are in obstacle_marg
# time_star is:  39
# time_star is from def:  39
# Total cost for all players:  [3.1632115844095883]
# current trajectory cost is:  [3.1632115844095883]
# new trajectory cost is:  [3.157351188440427]
# step-size for this is:  0.12157665459056936
# current trajectory cost is:  [3.1632115844095883]
# new trajectory cost is:  [3.157351188440427]
# step-size for this is:  0.12157665459056936
# we are in target_marg
# target_marg_func at tau* is:  [3.15735119]
# time_star is:  53
# time_star is from def:  53
# Total cost for all players:  [3.157351188440427]
# a is:  39
# b is:  2
# c is:  (12.0, 24.0)
# current trajectory cost is:  [3.157351188440427]
# new trajectory cost is:  [3.123946745204116]
# step-size for this is:  1.0
# a is:  39
# b is:  2
# c is:  (12.0, 24.0)
# current trajectory cost is:  [3.157351188440427]
# new trajectory cost is:  [3.123946745204116]
# step-size for this is:  1.0
# obs_marg_func at tau* is:  [3.12394675]
# we are in obstacle_marg
# time_star is:  39
# time_star is from def:  39
# Total cost for all players:  [3.123946745204116]
# current trajectory cost is:  [3.123946745204116]
# new trajectory cost is:  [3.124971376760813]
# step-size for this is:  0.28242953648100017
# current trajectory cost is:  [3.123946745204116]
# new trajectory cost is:  [3.124971376760813]
# step-size for this is:  0.28242953648100017
# we are in target_marg
# target_marg_func at tau* is:  [3.12497138]
# time_star is:  53
# time_star is from def:  53
# Total cost for all players:  [3.124971376760813]
# a is:  40
# b is:  2
# c is:  (12.0, 24.0)
# current trajectory cost is:  [3.124971376760813]
# new trajectory cost is:  [3.020726136444508]
# step-size for this is:  1.0
# a is:  40
# b is:  2
# c is:  (12.0, 24.0)
# current trajectory cost is:  [3.124971376760813]
# new trajectory cost is:  [3.020726136444508]
# step-size for this is:  1.0
# obs_marg_func at tau* is:  [3.02072614]
# we are in obstacle_marg
# time_star is:  40
# time_star is from def:  40
# Total cost for all players:  [3.020726136444508]
# current trajectory cost is:  [3.020726136444508]
# new trajectory cost is:  [3.019029056170382]
# step-size for this is:  0.25418658283290013
# current trajectory cost is:  [3.020726136444508]
# new trajectory cost is:  [3.019029056170382]
# step-size for this is:  0.25418658283290013
# we are in target_marg
# target_marg_func at tau* is:  [3.01902906]
# time_star is:  54
# time_star is from def:  54
# Total cost for all players:  [3.019029056170382]
# a is:  40
# b is:  2
# c is:  (12.0, 24.0)
# current trajectory cost is:  [3.019029056170382]
# new trajectory cost is:  [2.9632568943477056]
# step-size for this is:  1.0
# a is:  40
# b is:  2
# c is:  (12.0, 24.0)
# current trajectory cost is:  [3.019029056170382]
# new trajectory cost is:  [2.9632568943477056]
# step-size for this is:  1.0
# obs_marg_func at tau* is:  [2.96325689]
# we are in obstacle_marg
# time_star is:  40
# time_star is from def:  40
# Total cost for all players:  [2.9632568943477056]
# current trajectory cost is:  [2.9632568943477056]
# new trajectory cost is:  [2.9636583560358147]
# step-size for this is:  0.5314410000000002
# current trajectory cost is:  [2.9632568943477056]
# new trajectory cost is:  [2.9636583560358147]
# step-size for this is:  0.5314410000000002
# we are in target_marg
# target_marg_func at tau* is:  [2.96365836]
# time_star is:  54
# time_star is from def:  54
# Total cost for all players:  [2.9636583560358147]
# a is:  40
# b is:  2
# c is:  (12.0, 24.0)
# current trajectory cost is:  [2.9636583560358147]
# new trajectory cost is:  [2.7972853293289797]
# step-size for this is:  1.0
# a is:  40
# b is:  2
# c is:  (12.0, 24.0)
# current trajectory cost is:  [2.9636583560358147]
# new trajectory cost is:  [2.7972853293289797]
# step-size for this is:  1.0
# obs_marg_func at tau* is:  [2.79728533]
# we are in obstacle_marg
# time_star is:  40
# time_star is from def:  40
# Total cost for all players:  [2.7972853293289797]
# current trajectory cost is:  [2.7972853293289797]
# new trajectory cost is:  [2.7875302075549895]
# step-size for this is:  0.38742048900000015
# current trajectory cost is:  [2.7972853293289797]
# new trajectory cost is:  [2.7875302075549895]
# step-size for this is:  0.38742048900000015
# we are in target_marg
# target_marg_func at tau* is:  [2.78753021]
# time_star is:  54
# time_star is from def:  54
# Total cost for all players:  [2.7875302075549895]
# a is:  40
# b is:  2
# c is:  (12.0, 24.0)
# current trajectory cost is:  [2.7875302075549895]
# new trajectory cost is:  [2.7241480336373405]
# step-size for this is:  1.0
# a is:  40
# b is:  2
# c is:  (12.0, 24.0)
# current trajectory cost is:  [2.7875302075549895]
# new trajectory cost is:  [2.7241480336373405]
# step-size for this is:  1.0
# obs_marg_func at tau* is:  [2.72414803]
# we are in obstacle_marg
# time_star is:  40
# time_star is from def:  40
# Total cost for all players:  [2.7241480336373405]
# current trajectory cost is:  [2.7241480336373405]
# new trajectory cost is:  [2.706089527749456]
# step-size for this is:  0.5904900000000002
# current trajectory cost is:  [2.7241480336373405]
# new trajectory cost is:  [2.706089527749456]
# step-size for this is:  0.5904900000000002
# we are in target_marg
# target_marg_func at tau* is:  [2.70608953]
# time_star is:  55
# time_star is from def:  55
# Total cost for all players:  [2.706089527749456]
# a is:  40
# b is:  2
# c is:  (12.0, 24.0)
# current trajectory cost is:  [2.706089527749456]
# new trajectory cost is:  [2.5708602448468127]
# step-size for this is:  1.0
# a is:  40
# b is:  2
# c is:  (12.0, 24.0)
# current trajectory cost is:  [2.706089527749456]
# new trajectory cost is:  [2.5708602448468127]
# step-size for this is:  1.0
# obs_marg_func at tau* is:  [2.57086024]
# we are in obstacle_marg
# time_star is:  40
# time_star is from def:  40
# Total cost for all players:  [2.5708602448468127]
# current trajectory cost is:  [2.5708602448468127]
# new trajectory cost is:  [2.538061944049679]
# step-size for this is:  0.7290000000000001
# current trajectory cost is:  [2.5708602448468127]
# new trajectory cost is:  [2.538061944049679]
# step-size for this is:  0.7290000000000001
# we are in target_marg
# target_marg_func at tau* is:  [2.53806194]
# time_star is:  55
# time_star is from def:  55
# Total cost for all players:  [2.538061944049679]
# a is:  40
# b is:  2
# c is:  (12.0, 24.0)
# current trajectory cost is:  [2.538061944049679]
# new trajectory cost is:  [2.39248731941261]
# step-size for this is:  1.0
# a is:  40
# b is:  2
# c is:  (12.0, 24.0)
# current trajectory cost is:  [2.538061944049679]
# new trajectory cost is:  [2.39248731941261]
# step-size for this is:  1.0
# obs_marg_func at tau* is:  [2.39248732]
# we are in obstacle_marg
# time_star is:  40
# time_star is from def:  40
# Total cost for all players:  [2.39248731941261]
# current trajectory cost is:  [2.39248731941261]
# new trajectory cost is:  [2.3897528947009583]
# step-size for this is:  0.9
# current trajectory cost is:  [2.39248731941261]
# new trajectory cost is:  [2.3897528947009583]
# step-size for this is:  0.9
# we are in target_marg
# target_marg_func at tau* is:  [2.38975289]
# time_star is:  56
# time_star is from def:  56
# Total cost for all players:  [2.3897528947009583]
# SIGINT caught! Saving log data...
# ...done, exiting!
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 0
# /Users/duyn/miniforge3/envs/reach-avoid-games/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3452: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
